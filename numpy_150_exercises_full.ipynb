# %% [markdown]
# # 📘 Ultimate NumPy 150 Exercise Notebook
# Practice all important NumPy coding patterns in one place.
# Solve each exercise in the code cell below it.
# ---

# %%
# Common imports for all exercises
import numpy as np

# %% [markdown]
# ## 🔹 Level 1 — Easy (Exercises 1–30)

# %% [markdown]
# ## 📝 Exercise 1
# **Problem:** Create a 1D array of numbers 1–20.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 2
# **Problem:** Create a 5×5 matrix of zeros.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 3
# **Problem:** Create a 4×4 matrix of ones.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 4
# **Problem:** Create a 3×3 identity matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 5
# **Problem:** Create an array of even numbers from 2 to 50.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 6
# **Problem:** Create an array of 30 random integers between 0 and 100.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 7
# **Problem:** Create an array of 20 random floats between 0 and 1.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 8
# **Problem:** Create a float32 array of numbers 1–10.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 9
# **Problem:** Create an int8 array of numbers 1–10.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 10
# **Problem:** Create an array of 10 consecutive dates.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 11
# **Problem:** Slice the first 6 elements of an array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 12
# **Problem:** Slice the last 4 elements of an array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 13
# **Problem:** Reverse an array using slicing.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 14
# **Problem:** Extract the 2nd row from a 3×4 matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 15
# **Problem:** Extract the 4th column from a matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 16
# **Problem:** Extract a 2×2 block from a 3×3 matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 17
# **Problem:** Add 10 to every element in an array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 18
# **Problem:** Multiply all elements in an array by -3.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 19
# **Problem:** Compute the element-wise square of an array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 20
# **Problem:** Compute the square root of all elements in an array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 21
# **Problem:** Perform element-wise addition of two arrays.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 22
# **Problem:** Perform element-wise multiplication of two arrays.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 23
# **Problem:** Compute the sum of all elements in an array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 24
# **Problem:** Compute the mean of an array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 25
# **Problem:** Compute the standard deviation of an array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 26
# **Problem:** Compute the row-wise sum of a matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 27
# **Problem:** Compute the column-wise sum of a matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 28
# **Problem:** Reshape a 12-element 1D array into a 3×4 matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 29
# **Problem:** Flatten a 2D matrix into a 1D array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 30
# **Problem:** Convert a 1D array to a column vector.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 🔹 Level 2 — Medium (Exercises 31–70)

# %% [markdown]
# ## 📝 Exercise 31
# **Problem:** Extract all even numbers from an array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 32
# **Problem:** Extract all values greater than 50 from an array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 33
# **Problem:** Replace all negative values in an array with 0.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 34
# **Problem:** Count how many values in an array are greater than 20.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 35
# **Problem:** Extract all odd values from an array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 36
# **Problem:** Add a row vector to a 3×3 matrix using broadcasting.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 37
# **Problem:** Add a column vector to a 4×4 matrix using broadcasting.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 38
# **Problem:** Convert an array of Celsius values to Fahrenheit using broadcasting.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 39
# **Problem:** Normalize each row of a matrix using broadcasting.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 40
# **Problem:** Multiply each column of a matrix by a given vector using broadcasting.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 41
# **Problem:** Extract elements at positions [0, 3, 5, 7] from a 1D array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 42
# **Problem:** Select rows with indices [0, 2, 4] from a matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 43
# **Problem:** Select elements at positions (0,1), (2,2), and (3,0) from a matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 44
# **Problem:** Reverse the row order of a 2D matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 45
# **Problem:** Reverse the column order of a 2D matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 46
# **Problem:** Generate a 6×6 matrix of random integers between 0 and 100.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 47
# **Problem:** Generate 500 samples from a normal distribution.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 48
# **Problem:** Generate 500 samples from a Poisson distribution.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 49
# **Problem:** Randomly shuffle a 1D array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 50
# **Problem:** Randomly choose 10 values from an array with given probabilities.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 51
# **Problem:** Vertically stack two 1D arrays.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 52
# **Problem:** Horizontally stack two 1D arrays.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 53
# **Problem:** Column-stack two 1D arrays into a 2D array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 54
# **Problem:** Split a 1D array into 4 equal parts.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 55
# **Problem:** Split a 1D array into 3 unequal parts.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 56
# **Problem:** Split a 4×4 matrix into four 2×2 blocks.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 57
# **Problem:** Sort the elements of a 1D array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 58
# **Problem:** Sort the rows of a 2D matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 59
# **Problem:** Sort the columns of a 2D matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 60
# **Problem:** Use argsort to get the sorted index order of a 1D array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 61
# **Problem:** Remove duplicate values from a 1D array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 62
# **Problem:** Count the occurrences of each unique value in an array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 63
# **Problem:** Find the union of two 1D arrays.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 64
# **Problem:** Find the intersection of two 1D arrays.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 65
# **Problem:** Find the set difference A − B for two 1D arrays A and B.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 66
# **Problem:** Convert a 1D array into a row vector (shape (1, n)).
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 67
# **Problem:** Convert a 1D array into a column vector (shape (n, 1)).
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 68
# **Problem:** Reshape 24 numbers into a 3×4×2 array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 69
# **Problem:** Tile the pattern [1, 2, 3] five times into a 1D array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 70
# **Problem:** Repeat each element in [1, 2, 3] four times.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 🔹 Level 3 — Hard (Exercises 71–110)

# %% [markdown]
# ## 📝 Exercise 71
# **Problem:** Compute the determinant of a 3×3 matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 72
# **Problem:** Compute the inverse of a 3×3 matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 73
# **Problem:** Compute the rank of a matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 74
# **Problem:** Compute the eigenvalues of a matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 75
# **Problem:** Compute the eigenvectors of a matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 76
# **Problem:** Compute the singular value decomposition (SVD) of a random matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 77
# **Problem:** Verify numerically that U @ np.diag(S) @ Vt reconstructs the original matrix A from its SVD.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 78
# **Problem:** Multiply a 20×10 matrix with a 10×5 matrix using NumPy.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 79
# **Problem:** Compute the trace (sum of diagonal elements) of a matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 80
# **Problem:** Solve a 3×3 linear system Ax = b using NumPy.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 81
# **Problem:** Compute the Frobenius norm of a matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 82
# **Problem:** Select all rows of a matrix where the sum of the row is greater than 20.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 83
# **Problem:** Select all rows of a matrix where the first column value is greater than the second column value.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 84
# **Problem:** Replace all values in an array that are less than the mean with the mean value.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 85
# **Problem:** Replace all values greater than mean + standard deviation with the mean value.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 86
# **Problem:** Extract the diagonal elements of a matrix into a 1D array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 87
# **Problem:** Replace the diagonal elements of a square matrix with 0.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 88
# **Problem:** Count how many zero values exist in a matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 89
# **Problem:** Extract only the positive values from an array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 90
# **Problem:** Simulate 1,000,000 coin flips and count how many are heads (1 vs 0).
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 91
# **Problem:** Simulate rolling a fair six-sided die 10,000 times and compute the frequency of each face.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 92
# **Problem:** Generate a 1D random walk of length 1000.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 93
# **Problem:** Simulate heights of 500 people with a normal distribution (mean 170, std 10).
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 94
# **Problem:** Perform bootstrap sampling (random sampling with replacement) from a 1D dataset.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 95
# **Problem:** Compute y = x³ + 2x² + 3x for x from 0 to 100 using vectorized operations.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 96
# **Problem:** Vectorize a Python function f(x) = x² + 1 and apply it to an array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 97
# **Problem:** Compute the element-wise sigmoid function 1 / (1 + exp(-x)) for an array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 98
# **Problem:** Compute the element-wise ReLU function max(0, x) for an array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 99
# **Problem:** Compute the softmax of a 1D array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 100
# **Problem:** Compute the pairwise Euclidean distances between 10 random 2D points.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 101
# **Problem:** Compute the cosine similarity matrix for 10 random vectors.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 102
# **Problem:** Normalize each row of a matrix to unit L2 norm.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 103
# **Problem:** Apply min–max scaling to each column of a matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 104
# **Problem:** Apply z-score standardization to each column of a matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 105
# **Problem:** Compute the column-wise variance of a matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 106
# **Problem:** Extract all rows of a matrix where the maximum value in the row is greater than 50.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 107
# **Problem:** Remove all rows from a matrix that contain at least one negative value.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 108
# **Problem:** Replace all NaN values in a 2D array with the mean of their respective column.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 109
# **Problem:** Create a boolean mask that detects NaN values in a 2D array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 110
# **Problem:** Reshape a 1D array into a 3D array of a compatible shape using reshape.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 🔹 Level 4 — University Exam Level (Exercises 111–130)

# %% [markdown]
# ## 📝 Exercise 111
# **Problem:** Demonstrate the difference between a view and a copy by modifying an array created with ravel() and flatten().
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 112
# **Problem:** Show broadcasting between arrays of shapes (3, 1) and (1, 3) and compute their sum.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 113
# **Problem:** Demonstrate the difference between np.dot, np.matmul, and the @ operator on sample arrays.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 114
# **Problem:** Compute the correlation matrix of a 2D dataset using NumPy.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 115
# **Problem:** Compute the covariance matrix of a 2D dataset using NumPy.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 116
# **Problem:** Sort a 2D matrix by the values in a specific column.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 117
# **Problem:** Use np.where to label elements of an array as 1 if they are greater than 50, otherwise 0.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 118
# **Problem:** Compute the Mean Squared Error (MSE) between two 1D arrays.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 119
# **Problem:** Compute the accuracy of binary predictions given y_true and y_pred arrays.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 120
# **Problem:** Remove duplicate rows from a 2D matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 121
# **Problem:** Find the most frequent value in a 1D array using NumPy operations only.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 122
# **Problem:** Extract columns 0 and 2 from a 5×5 matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 123
# **Problem:** Split a dataset into train and test sets using only NumPy (no sklearn).
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 124
# **Problem:** Replace outliers (values greater than mean + 2*std or less than mean - 2*std) with the median value.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 125
# **Problem:** Swap the first and last rows of a matrix.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 126
# **Problem:** Shuffle the rows of a 2D matrix in-place.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 127
# **Problem:** Generate an 8×8 checkerboard pattern using NumPy.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 128
# **Problem:** Generate a random integer matrix and sort each row individually.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 129
# **Problem:** Compute the cumulative sum of a 1D array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 130
# **Problem:** Compute the cumulative product of a 1D array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 🔹 Level 5 — Professional ML Engineer (Exercises 131–150)

# %% [markdown]
# ## 📝 Exercise 131
# **Problem:** Generate polynomial features up to degree 2 for a 2D feature matrix using NumPy only.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 132
# **Problem:** Implement batch normalization (zero mean, unit variance) per column for a 2D array.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 133
# **Problem:** Implement gradient descent to fit a linear regression model using NumPy.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 134
# **Problem:** Implement L2-regularized linear regression cost function using NumPy.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 135
# **Problem:** Compute binary cross-entropy loss given y_true and predicted probabilities y_pred.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 136
# **Problem:** Compute the softmax function for each row in a 2D array (batch of samples).
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 137
# **Problem:** Compute the confusion matrix for binary classification using NumPy.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 138
# **Problem:** Compute precision, recall, and F1-score for binary classification using NumPy only.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 139
# **Problem:** One-hot encode a 1D array of integer class labels.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 140
# **Problem:** Decode a 2D one-hot encoded array back into a 1D array of class labels.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 141
# **Problem:** Compute the Euclidean distance matrix for 100 random 2D points.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 142
# **Problem:** Compute the Mahalanobis distance between points in a dataset using NumPy.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 143
# **Problem:** Implement Principal Component Analysis (PCA) using eigen decomposition in NumPy.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 144
# **Problem:** Project a dataset onto its top 2 principal components using NumPy.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 145
# **Problem:** Implement k-NN distance computation (pairwise distances) using NumPy without explicit Python loops.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 146
# **Problem:** Create a dropout mask for a 2D input array given a dropout rate, and apply it to the input.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 147
# **Problem:** Implement the gradient of Mean Squared Error (MSE) loss with respect to predictions.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 148
# **Problem:** Simulate 1000 steps of gradient descent on a simple linear regression problem using NumPy.
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 149
# **Problem:** Implement matrix multiplication manually using broadcasting and sum (without using @, dot, or matmul).
#
# ### ✏️ Your Code:

# %%
# Write your solution here

# %% [markdown]
# ## 📝 Exercise 150
# **Problem:** Build a complete linear regression pipeline: generate data, fit using the normal equation, make predictions, and compute MSE.
#
# ### ✏️ Your Code:

# %%
# Write your solution here
