# %% [markdown]
# # NumPy Practice – Day 7
#
# Topic: ML-Style End-to-End Problems
#
# Instructions:
# - Read each question carefully.
# - Write your solution in the code cell below each question.
# - Do not modify the questions.
#
# Notes:
# - Use NumPy only (no pandas, scikit-learn).
# - You may define helper functions in the code cells.

# %% [markdown]
# ## Question 1
# Normalize a dataset row-wise.

# %%
# Write your code here

# %% [markdown]
# ## Question 2
# Normalize a dataset column-wise.

# %%
# Write your code here

# %% [markdown]
# ## Question 3
# One-hot encode labels.

# %%
# Write your code here

# %% [markdown]
# ## Question 4
# Decode one-hot labels.

# %%
# Write your code here

# %% [markdown]
# ## Question 5
# Implement train-test split.

# %%
# Write your code here

# %% [markdown]
# ## Question 6
# Shuffle a dataset while keeping labels aligned.

# %%
# Write your code here

# %% [markdown]
# ## Question 7
# Implement linear regression using the normal equation.

# %%
# Write your code here

# %% [markdown]
# ## Question 8
# Implement gradient descent for linear regression.

# %%
# Write your code here

# %% [markdown]
# ## Question 9
# Compute MSE loss.

# %%
# Write your code here

# %% [markdown]
# ## Question 10
# Compute accuracy.

# %%
# Write your code here

# %% [markdown]
# ## Question 11
# Implement softmax.

# %%
# Write your code here

# %% [markdown]
# ## Question 12
# Implement batch softmax.

# %%
# Write your code here

# %% [markdown]
# ## Question 13
# Implement a dropout mask.

# %%
# Write your code here

# %% [markdown]
# ## Question 14
# Simulate a random walk.

# %%
# Write your code here

# %% [markdown]
# ## Question 15
# Estimate pi using Monte Carlo simulation.

# %%
# Write your code here

# %% [markdown]
# ## Question 16
# Implement bootstrap sampling.

# %%
# Write your code here

# %% [markdown]
# ## Question 17
# Compute a confusion matrix.

# %%
# Write your code here

# %% [markdown]
# ## Question 18
# Implement precision and recall.

# %%
# Write your code here

# %% [markdown]
# ## Question 19
# Implement k-NN distance computation.

# %%
# Write your code here

# %% [markdown]
# ## Question 20
# Build a mini ML pipeline using NumPy only.

# %%
# Write your code here
