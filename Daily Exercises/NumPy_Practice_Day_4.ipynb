# %% [markdown]
# # NumPy Practice – Day 4
#
# Topic: Reshaping, Stacking, Splitting, Sorting, and Set Operations
#
# Instructions:
# - Read each question carefully.
# - Write your solution in the code cell below each question.
# - Do not modify the questions.

# %% [markdown]
# ## Question 1
# Reshape a 1D array into 2D.

# %%
# Write your code here

# %% [markdown]
# ## Question 2
# Flatten a matrix.

# %%
# Write your code here

# %% [markdown]
# ## Question 3
# Use ravel vs flatten.

# %%
# Write your code here

# %% [markdown]
# ## Question 4
# Convert a 1D array to row and column vector.

# %%
# Write your code here

# %% [markdown]
# ## Question 5
# Stack arrays vertically.

# %%
# Write your code here

# %% [markdown]
# ## Question 6
# Stack arrays horizontally.

# %%
# Write your code here

# %% [markdown]
# ## Question 7
# Column-stack two arrays.

# %%
# Write your code here

# %% [markdown]
# ## Question 8
# Split an array into equal parts.

# %%
# Write your code here

# %% [markdown]
# ## Question 9
# Split an array into unequal parts.

# %%
# Write your code here

# %% [markdown]
# ## Question 10
# Split a matrix into blocks.

# %%
# Write your code here

# %% [markdown]
# ## Question 11
# Sort a 1D array.

# %%
# Write your code here

# %% [markdown]
# ## Question 12
# Sort a matrix row-wise.

# %%
# Write your code here

# %% [markdown]
# ## Question 13
# Sort a matrix column-wise.

# %%
# Write your code here

# %% [markdown]
# ## Question 14
# Get sorted indices using argsort.

# %%
# Write your code here

# %% [markdown]
# ## Question 15
# Remove duplicate values.

# %%
# Write your code here

# %% [markdown]
# ## Question 16
# Count occurrences of values.

# %%
# Write your code here

# %% [markdown]
# ## Question 17
# Find union of two arrays.

# %%
# Write your code here

# %% [markdown]
# ## Question 18
# Find intersection of two arrays.

# %%
# Write your code here

# %% [markdown]
# ## Question 19
# Find set difference of two arrays.

# %%
# Write your code here

# %% [markdown]
# ## Question 20
# Tile a pattern multiple times.

# %%
# Write your code here
