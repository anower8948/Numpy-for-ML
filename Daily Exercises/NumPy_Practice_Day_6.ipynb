# %% [markdown]
# # NumPy Practice – Day 6
#
# Topic: Linear Algebra (ML Core)
#
# Instructions:
# - Read each question carefully.
# - Write your solution in the code cell below each question.
# - Do not modify the questions.
#
# Tip:
# - Use numpy.linalg functions where appropriate.

# %% [markdown]
# ## Question 1
# Matrix multiplication.

# %%
# Write your code here

# %% [markdown]
# ## Question 2
# Compute transpose.

# %%
# Write your code here

# %% [markdown]
# ## Question 3
# Compute determinant.

# %%
# Write your code here

# %% [markdown]
# ## Question 4
# Compute inverse.

# %%
# Write your code here

# %% [markdown]
# ## Question 5
# Solve linear system Ax=b.

# %%
# Write your code here

# %% [markdown]
# ## Question 6
# Compute eigenvalues.

# %%
# Write your code here

# %% [markdown]
# ## Question 7
# Compute eigenvectors.

# %%
# Write your code here

# %% [markdown]
# ## Question 8
# Perform SVD.

# %%
# Write your code here

# %% [markdown]
# ## Question 9
# Reconstruct matrix from SVD.

# %%
# Write your code here

# %% [markdown]
# ## Question 10
# Compute Frobenius norm.

# %%
# Write your code here

# %% [markdown]
# ## Question 11
# Compute L1 and L2 norms.

# %%
# Write your code here

# %% [markdown]
# ## Question 12
# Check matrix rank.

# %%
# Write your code here

# %% [markdown]
# ## Question 13
# Compute cosine similarity.

# %%
# Write your code here

# %% [markdown]
# ## Question 14
# Compute Euclidean distance matrix.

# %%
# Write your code here

# %% [markdown]
# ## Question 15
# Implement PCA manually.

# %%
# Write your code here

# %% [markdown]
# ## Question 16
# Project data using PCA.

# %%
# Write your code here

# %% [markdown]
# ## Question 17
# Compute batch dot products.

# %%
# Write your code here

# %% [markdown]
# ## Question 18
# Compare dot, matmul, and @.

# %%
# Write your code here

# %% [markdown]
# ## Question 19
# Implement Mahalanobis distance.

# %%
# Write your code here

# %% [markdown]
# ## Question 20
# Check positive definiteness.

# %%
# Write your code here
