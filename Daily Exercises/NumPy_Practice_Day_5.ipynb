# %% [markdown]
# # NumPy Practice – Day 5
#
# Topic: Aggregation, Statistics, and Performance
#
# Instructions:
# - Read each question carefully.
# - Write your solution in the code cell below each question.
# - Do not modify the questions.
#
# Note:
# - For timing, you may use time/timeit or Jupyter %%time / %%timeit magics.

# %% [markdown]
# ## Question 1
# Compute sum, mean, and standard deviation of an array.

# %%
# Write your code here

# %% [markdown]
# ## Question 2
# Compute row-wise sum of a 2D array.

# %%
# Write your code here

# %% [markdown]
# ## Question 3
# Compute column-wise mean of a 2D array.

# %%
# Write your code here

# %% [markdown]
# ## Question 4
# Compute minimum and maximum of an array.

# %%
# Write your code here

# %% [markdown]
# ## Question 5
# Compute cumulative sum of an array.

# %%
# Write your code here

# %% [markdown]
# ## Question 6
# Compute cumulative product of an array.

# %%
# Write your code here

# %% [markdown]
# ## Question 7
# Compute percentile values of an array.

# %%
# Write your code here

# %% [markdown]
# ## Question 8
# Compute variance manually (without using np.var).

# %%
# Write your code here

# %% [markdown]
# ## Question 9
# Normalize an array using z-score.

# %%
# Write your code here

# %% [markdown]
# ## Question 10
# Apply min-max scaling to data.

# %%
# Write your code here

# %% [markdown]
# ## Question 11
# Detect outliers using z-score.

# %%
# Write your code here

# %% [markdown]
# ## Question 12
# Replace outliers with the median.

# %%
# Write your code here

# %% [markdown]
# ## Question 13
# Compute a correlation matrix.

# %%
# Write your code here

# %% [markdown]
# ## Question 14
# Compute a covariance matrix.

# %%
# Write your code here

# %% [markdown]
# ## Question 15
# Use np.any and np.all on boolean conditions.

# %%
# Write your code here

# %% [markdown]
# ## Question 16
# Measure execution time of an operation.

# %%
# Write your code here

# %% [markdown]
# ## Question 17
# Compare float32 vs float64 (precision or memory/time).

# %%
# Write your code here

# %% [markdown]
# ## Question 18
# Count NaN values in an array.

# %%
# Write your code here

# %% [markdown]
# ## Question 19
# Replace NaN values with the mean.

# %%
# Write your code here

# %% [markdown]
# ## Question 20
# Apply memory usage optimization techniques.

# %%
# Write your code here
