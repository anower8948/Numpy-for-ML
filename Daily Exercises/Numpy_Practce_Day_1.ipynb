# %% [markdown]
# # NumPy Practice – Day 1
#
# This notebook contains practice problems on NumPy array creation, data types, and memory concepts.
#
# Instructions:
# - Read each question carefully.
# - Write your solution in the code cell below each question.
# - Do not modify the questions.

# %% [markdown]
# ## Question 1
# Create a 1D NumPy array from 1 to 50.

# %%
# Write your code here

# %% [markdown]
# ## Question 2
# Create a 5×5 matrix filled with zeros.

# %%
# Write your code here

# %% [markdown]
# ## Question 3
# Create a 3×4 matrix filled with ones.

# %%
# Write your code here

# %% [markdown]
# ## Question 4
# Create an identity matrix of size 6.

# %%
# Write your code here

# %% [markdown]
# ## Question 5
# Create an array of even numbers from 2 to 100.

# %%
# Write your code here

# %% [markdown]
# ## Question 6
# Create an array of 20 equally spaced numbers between 0 and 1.

# %%
# Write your code here

# %% [markdown]
# ## Question 7
# Create an array of 15 random integers between 10 and 50.

# %%
# Write your code here

# %% [markdown]
# ## Question 8
# Create a float32 array from 1 to 10.

# %%
# Write your code here

# %% [markdown]
# ## Question 9
# Create an int8 array from 1 to 10.

# %%
# Write your code here

# %% [markdown]
# ## Question 10
# Create a boolean NumPy array from a Python list.

# %%
# Write your code here

# %% [markdown]
# ## Question 11
# Convert an integer NumPy array to float type.

# %%
# Write your code here

# %% [markdown]
# ## Question 12
# Create a NumPy array containing complex numbers.

# %%
# Write your code here

# %% [markdown]
# ## Question 13
# Create a datetime64 array of 7 consecutive days.

# %%
# Write your code here

# %% [markdown]
# ## Question 14
# Check the dtype, shape, and size of a NumPy array.

# %%
# Write your code here

# %% [markdown]
# ## Question 15
# Change the dtype of an array without modifying the original array.

# %%
# Write your code here

# %% [markdown]
# ## Question 16
# Create an empty array and fill it later with values.

# %%
# Write your code here

# %% [markdown]
# ## Question 17
# Create a constant array filled entirely with the value 9.

# %%
# Write your code here

# %% [markdown]
# ## Question 18
# Compare the memory size of int32 and int64 arrays.

# %%
# Write your code here

# %% [markdown]
# ## Question 19
# Copy a NumPy array and verify that the copy is independent.

# %%
# Write your code here

# %% [markdown]
# ## Question 20
# Create a range array using arange.

# %%
# Write your code here
